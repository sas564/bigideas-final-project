# %%
import pandas as pd
# %matplotlib inline
data = pd.read_csv("water.csv")
data.plot()

# %%
import pandas as pd
# %matplotlib inline
data = pd.read_csv("art.csv")

estimated = data.sort_values(by='neighborhood', ascending=True)
dumpingplot = data.head(65)
fruit_counts = data.groupby(["neighborhood", "title"]).size().rename("Count")
data.join(fruit_counts, on=["neighborhood", "title"])
art = data['neighborhood'].value_counts()
